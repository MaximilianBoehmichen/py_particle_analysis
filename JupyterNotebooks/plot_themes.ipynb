# %%
from pypana.plots.themes import print_themes

# %%
print_themes()
# Out:
# ibm    (IBMTheme)────────────────────────────────────────────────────
#    1.    1st             #648fff
#    2.    2nd             #ffb000
#    3.    3rd             #dc267f
#    4.    4th             #fe6100
#    5.    5th             #785ef0
#    6.    black           #000000
# colorful    (ColorfulTheme)────────────────────────────────────────────────────
#    1.    purple          #69085A
#    2.    dark blue       #0F1B5F
#    3.    light blue      #00778A
#    4.    green           #007C30
#    5.    grass green     #679A1D
#    6.    yellow          #FFDC00
#    7.    dark yellow     #F9BA00
#    8.    orange          #D64C13
#    9.    red             #C4071B
#   10.    dark red        #9C0D16
# wong    (WongTheme)────────────────────────────────────────────────────
#    1.    orange          #e69f00
#    2.    sky blue        #56b4e9
#    3.    bluish green    #009e73
#    4.    yellow          #f0e442
#    5.    blue            #0072b2
#    6.    vermillion      #d55e00
# ...
